# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
world_data = pd.read_csv('CSWS_Population.csv')

# %%
world_data.head()
# Out:
#   country countryCode  year  lifeExpectancy  populationFemale  populationMale  \
# 0   Aruba         ABW  1960          65.662           27637.0         26574.0
# 1   Aruba         ABW  1961          66.074           28254.0         27184.0
# 2   Aruba         ABW  1962          66.444           28655.0         27570.0
# 3   Aruba         ABW  1963          66.787           28907.0         27788.0
# 4   Aruba         ABW  1964          67.113           29094.0         27938.0
#
#    gdpPerCapita  population
# 0           NaN     54211.0
# 1           NaN     55438.0
# 2           NaN     56225.0
# 3           NaN     56695.0
# 4           NaN     57032.0

# %%
Vietnam = world_data[world_data['country'] == "Vietnam"]
Vietnam.drop(['country', 'countryCode'], axis=1, inplace=True)
Vietnam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 14790 to 14847
# Data columns (total 6 columns):
# year                58 non-null int64
# lifeExpectancy      57 non-null float64
# populationFemale    58 non-null float64
# populationMale      58 non-null float64
# gdpPerCapita        33 non-null float64
# population          58 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 3.2 KB
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
Vietnam.describe()
# Out:
#               year  lifeExpectancy  populationFemale  populationMale  \
# count    58.000000       57.000000      5.800000e+01    5.800000e+01
# mean   1988.500000       68.524140      3.303913e+07    3.210318e+07
# std      16.886879        5.850385      9.814209e+06    9.601228e+06
# min    1960.000000       58.835000      1.655450e+07    1.611613e+07
# 25%    1974.250000       61.968000      2.437477e+07    2.355390e+07
# 50%    1988.500000       69.940000      3.353201e+07    3.250354e+07
# 75%    2002.750000       73.695000      4.189915e+07    4.065072e+07
# max    2017.000000       76.253000      4.826236e+07    4.727844e+07
#
#        gdpPerCapita    population
# count     33.000000  5.800000e+01
# mean     791.128894  6.514230e+07
# std      694.314097  1.941506e+07
# min       94.271269  3.267063e+07
# 25%      322.857048  4.792868e+07
# 50%      427.838026  6.603556e+07
# 75%     1210.691110  8.254987e+07
# max     2343.124575  9.554080e+07

# %%
sns.jointplot(x = 'gdpPerCapita', y = 'lifeExpectancy', data = Vietnam)
#sns.jointplot(Vietnam[['gdpPerCapita']], Vietnam[['lifeExpectancy']], data = Vietnam)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Vietnam.groupby('year').mean()[['gdpPerCapita']]
# Out:
#       gdpPerCapita
# year
# 1960           NaN
# 1961           NaN
# 1962           NaN
# 1963           NaN
# 1964           NaN
# 1965           NaN
# 1966           NaN
# 1967           NaN
# 1968           NaN
# 1969           NaN
# 1970           NaN
# 1971           NaN
# 1972           NaN
# 1973           NaN
# 1974           NaN
# 1975           NaN
# 1976           NaN
# 1977           NaN
# 1978           NaN
# 1979           NaN
# 1980           NaN
# 1981           NaN
# 1982           NaN
# 1983           NaN
# 1984           NaN
# 1985    230.873589
# 1986    421.658690
# 1987    573.847285
# 1988    389.256918
# 1989     94.271269
# 1990     94.880198
# 1991    137.982562
# 1992    138.716830
# 1993    181.654852
# 1994    220.309983
# 1995    275.750619
# 1996    322.857048
# 1997    346.579014
# 1998    346.827244
# 1999    361.294402
# 2000    388.270539
# 2001    402.825134
# 2002    427.838026
# 2003    477.989497
# 2004    543.865887
# 2005    683.596804
# ...

# %%
sns.scatterplot(x = 'gdpPerCapita', y = 'lifeExpectancy', data = Vietnam)
                
                #data=pd.DataFrame({'Y Test':y_test, 'Predicted Y':y_predict}))

# %%
Vietnam1 = Vietnam.set_index('year')
Vietnam1.head()
# Out:
#       lifeExpectancy  populationFemale  populationMale  gdpPerCapita  \
# year
# 1960          59.041        16554502.0      16116127.0           NaN
# 1961          59.722        17057908.0      16608864.0           NaN
# 1962          60.391        17572019.0      17112146.0           NaN
# 1963          61.024        18096738.0      17625353.0           NaN
# 1964          61.585        18632569.0      18148416.0           NaN
#
#       population
# year
# 1960  32670629.0
# 1961  33666772.0
# 1962  34684165.0
# 1963  35722091.0
# 1964  36780985.0

# %%
Vietnam2 = Vietnam1.drop(Vietnam1.index[0:25])
Vietnam2.head(33)
# Out:
#       lifeExpectancy  populationFemale  populationMale  gdpPerCapita  \
# year
# 1985          68.982        31022559.0      30026814.0    230.873589
# 1986          69.300        31732368.0      30727192.0    421.658690
# 1987          69.626        32447950.0      31433347.0    573.847285
# 1988          69.940        33168823.0      32144885.0    389.256918
# 1989          70.242        33895200.0      32862202.0     94.271269
# 1990          70.536        34625677.0      33583928.0     94.880198
# 1991          70.826        35360477.0      34310425.0    137.982562
# 1992          71.113        36094326.0      35036122.0    138.716830
# 1993          71.399        36813719.0      35746708.0    181.654852
# 1994          71.685        37501305.0      36423777.0    220.309983
# 1995          71.968        38144723.0      37054254.0    275.750619
# 1996          72.248        38739143.0      37633576.0    322.857048
# ...

# %%
X_train = (Vietnam2['gdpPerCapita'].loc[:2005])
X_test = (Vietnam2['gdpPerCapita'].loc[2006:2016])

y_train = (Vietnam2['lifeExpectancy'].loc[:2005])
y_test = (Vietnam2['lifeExpectancy'].loc[2006:2016])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.dates as mdates

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# y_train_predict = lm.predict(X_train_poly)
# y_test_predict = lm.predict(X_test_poly)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-7e90ac1b8f30> in <module>()
#       1 lm = LinearRegression()
# ----> 2 lm.fit(X_train, y_train)
#       3 # y_train_predict = lm.predict(X_train_poly)
#       4 # y_test_predict = lm.predict(X_test_poly)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
plt.plot(Vietnam['year'], Vietnam['gdpPerCapita'])
plt.legend(['Vietnam'])
plt.xlabel('year')
plt.ylabel('GDP per capita')
plt.grid()
plt.show()

# %%
year_from_1985_to_2005 = (Vietnam['year']<=2005) & (Vietnam['year']>=1985)
year_from_2006_to_20017 = (Vietnam['year']<=2017) & (Vietnam['year']>=2006)

# %%
def plot_lifeExpectancy(year, outcome, prediction=None):
    # your code here
    plt.figure(figsize=(20,10))
    plt.xticks(rotation=45)
    plt.plot_date(year, outcome, fmt='b-', xdate=True, ydate=False, label='Real value')
    if prediction is not None:
        plt.plot_year(year, prediction, fmt='r-', xdate=True, ydate=False, label='Prediction value')
    plt.ylabel('lifeExpectancy')
    plt.title('Life Expectancy')
    plt.grid()
    plt.show()
    return

plot_lifeExpectancy(Vietnam['year'],Vietnam['lifeExpectancy'])
# plt.figure(figsize=(20,10))
# plt.xticks(rotation=45)
# plt.plot_date(Vietnam['year'], Vietnam['gdpPerCapita'], fmt='b-', xdate=True, ydate=False, label='Real value')
# plt.ylabel('GDP per Capita')
# plt.title('Vietnam GDP')
# plt.grid()
# plt.show()

# %%
y = Vietnam['lifeExpectancy']
X = Vietnam[['DATE2NUM','gdpPerCapita']]
nrow , ncol = Vietnam.shape

X_train = X.loc[nrow(.3),:]

#X_test = X.loc[np.floor(nrow*0.7):]

# y_train = y.loc[:nrow*0.7]
# y_test = y.loc[np.floor(nrow*0.3):]


# year_test = Vietnam['year'].loc[:np.floor(nrow*0.3)]
# year_train = Vietnam['year'].loc[np.floor(nrow*0.3):]

print (X_train)

# %%
plot_lifeExpectancy(year_train, y_train)

# %%
plot_lifeExpectancy(year_test, y_test)
